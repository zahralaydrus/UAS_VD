# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
import warnings 
warnings.filterwarnings('ignore')

# Import the numpy and pandas package
import numpy as np
import pandas as pd

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
uas = pd.read_csv("Company_data.csv")
uas
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
uas.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
import matplotlib.pyplot as plt 
import seaborn as sns

sns.pairplot(uas, x_vars=['TV', 'Radio','Newspaper'], 
             y_vars='Sales', size=4, aspect=1, kind='scatter')
plt.show()

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
sns.heatmap(uas.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
X = uas['TV']
y = uas['Sales']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
plt.scatter(X_train, y_train)
plt.plot(X_train, 6.948 + 0.054*X_train, 'r')
plt.show()

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
import statsmodels.api as sm

# Adding a constant to get an intercept
X_train_sm = sm.add_constant(X_train)

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
lr = sm.OLS(y_train, X_train_sm).fit()

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
X_test_sm = sm.add_constant(X_test)
y_test_pred = lr.predict(X_test_sm)

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
from sklearn.metrics import r2_score

r_squared = r2_score(y_test, y_test_pred)
r_squared
# Out:
# 0.7921031601245658

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split
X_train_lm, X_test_lm, y_train_lm, y_test_lm = train_test_split(X, y, train_size = 0.7, 
                                                                test_size = 0.3, random_state = 100)

# %%
# Shape of the train set without adding column
X_train_lm.shape

# Adding additional column to the train and test data
X_train_lm = X_train_lm.values.reshape(-1,1)
X_test_lm = X_test_lm.values.reshape(-1,1)

print(X_train_lm.shape)
print(X_test_lm.shape)
# Out:
# (140, 1)
# (60, 1)

# %%
from sklearn.linear_model import LinearRegression

# Creating an object of Linear Regression
lm = LinearRegression()

# Fit the model using .fit() method
lm.fit(X_train_lm, y_train_lm)
# Out:
# LinearRegression()

# %%
# Intercept value
print("Intercept :",lm.intercept_)

# Slope value
print('Slope :',lm.coef_)
# Out:
# Intercept : 6.9486832000013585
# Slope : [0.05454575]

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078

y_train_pred = lm.predict(X_train_lm)
y_test_pred = lm.predict(X_test_lm)


print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_test_pred))
# Out:
# 0.8157933136480388
# 0.792103160124566

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'r')
plt.show()

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
uas2 = pd.read_csv("testcpns.csv")
uas2
# Out:
#     toefl   ipk  pengalaman_kerja  diterima
# 0     780  4.00                 3         1
# 1     750  3.09                 4         1
# 2     690  3.03                 3         0
# 3     710  3.07                 5         1
# 4     680  3.09                 4         0
# 5     730  3.07                 6         1
# 6     690  2.03                 1         0
# 7     720  3.03                 4         1
# 8     740  3.03                 5         1
# 9     690  1.07                 1         0
# 10    610  2.07                 3         0
# 11    690  3.07                 5         1
# 12    710  3.07                 6         1
# 13    680  3.03                 4         0
# 14    770  3.03                 3         1
# 15    610  3.00                 1         0
# 16    580  2.07                 4         0
# 17    650  3.07                 6         1
# 18    540  2.07                 2         0
# 19    590  2.03                 3         0
# ...

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
uas2.describe()
# Out:
#             toefl        ipk  pengalaman_kerja   diterima
# count   40.000000  40.000000         40.000000  40.000000
# mean   654.000000   2.694500          3.425000   0.475000
# std     61.427464   0.653899          1.737778   0.505736
# min    540.000000   1.070000          1.000000   0.000000
# 25%    607.500000   2.070000          2.000000   0.000000
# 50%    660.000000   3.030000          4.000000   0.000000
# 75%    690.000000   3.070000          5.000000   1.000000
# max    780.000000   4.000000          6.000000   1.000000

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
sns.scatterplot(x="ipk",y="toefl",data =uas2, hue="diterima", size=5)
plt.show()

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
sns.scatterplot(x="pengalaman_kerja",y="toefl",data =uas2, hue="diterima", size=5)
plt.show()

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
sns.scatterplot(x="pengalaman_kerja",y="ipk",data =uas2, hue="diterima", size=5)
plt.show()

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
sns.pairplot(uas2, x_vars=['ipk', 'pengalaman_kerja','toefl'], 
             y_vars='diterima', size=4, aspect=1, kind='scatter')
plt.show()

# %%
X = uas2.iloc[:, :-1]
y = uas2.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
y_pred = model.predict(X_test)

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[6, 1],
#        [1, 4]], dtype=int64)

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
#Nama : Fathimah Azzahra Alaydrus
#NIM : 41819010078
uas2.loc[:, :]
uas2.loc[:,]
uas2.iloc[:, :]
uas2.iloc[:]
uas2
# Out:
#     toefl   ipk  pengalaman_kerja  diterima
# 0     780  4.00                 3         1
# 1     750  3.09                 4         1
# 2     690  3.03                 3         0
# 3     710  3.07                 5         1
# 4     680  3.09                 4         0
# 5     730  3.07                 6         1
# 6     690  2.03                 1         0
# 7     720  3.03                 4         1
# 8     740  3.03                 5         1
# 9     690  1.07                 1         0
# 10    610  2.07                 3         0
# 11    690  3.07                 5         1
# 12    710  3.07                 6         1
# 13    680  3.03                 4         0
# 14    770  3.03                 3         1
# 15    610  3.00                 1         0
# 16    580  2.07                 4         0
# 17    650  3.07                 6         1
# 18    540  2.07                 2         0
# 19    590  2.03                 3         0
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

uas2 = pd.read_csv("testcpns.csv", header=None, names=["toefl", "ipk", "pengalaman_kerja", "diterima"])
uas2.head()
# Out:
#    toefl    ipk  pengalaman_kerja  diterima
# 0  toefl    ipk  pengalaman_kerja  diterima
# 1    780      4                 3         1
# 2    750  03.09                 4         1
# 3    690  03.03                 3         0
# 4    710  03.07                 5         1

# %%
#Alamat Github : https://github.com/zahralaydrus
